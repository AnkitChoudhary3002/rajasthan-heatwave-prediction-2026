# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("rajasthan 2-5-2023-2026.csv")
df2 = pd.read_csv("rajasthan 6-8-2020 - 1-5-2023.csv")
df3 = pd.read_csv("rajasthan 15-9-2017--7-6-2020.csv")
df4 = pd.read_csv("rajasthan 20-12-2014 - 14-9-2020 .csv")
df5 = pd.read_csv("rajasthan 1-1-2014 - 19-12-2014.csv")

# %%
df1.head()
# Out:
#         name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  rajasthan  2023-05-02     89.6     71.4  79.4          90.3          71.4
# 1  rajasthan  2023-05-03     89.6     71.6  78.9          90.3          71.6
# 2  rajasthan  2023-05-04     89.6     69.6  79.8          92.3          69.6
# 3  rajasthan  2023-05-05     95.1     75.2  85.4          95.3          75.2
# 4  rajasthan  2023-05-06     98.6     77.0  87.1          97.8          77.0
#
#    feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       79.9  65.2      64.3  ...         23.3        9          10
# 1       79.2  64.5      63.7  ...         24.5       10          10
# 2       80.9  65.3      63.5  ...         23.5        9          10
# 3       85.6  62.4      48.9  ...         23.3        8          10
# 4       86.8  59.3      41.0  ...         25.8       10          10
#
#                sunrise               sunset  moonphase  \
# 0  2023-05-02T05:48:07  2023-05-02T18:59:57       0.39
# 1  2023-05-03T05:47:21  2023-05-03T19:00:30       0.42
# 2  2023-05-04T05:46:35  2023-05-04T19:01:04       0.45
# 3  2023-05-05T05:45:51  2023-05-05T19:01:37       0.50
# 4  2023-05-06T05:45:08  2023-05-06T19:02:10       0.52
#
#                conditions                                        description  \
# 0        Partially cloudy                  Partly cloudy throughout the day.
# 1  Rain, Partially cloudy  Partly cloudy throughout the day with late aft...
# 2  Rain, Partially cloudy  Partly cloudy throughout the day with afternoo...
# 3        Partially cloudy                  Partly cloudy throughout the day.
# 4        Partially cloudy                  Becoming cloudy in the afternoon.
#
#                 icon                 stations
# 0  partly-cloudy-day  VIJP,remote,42348099999
# 1               rain         VIJP,42348099999
# 2               rain         VIJP,42348099999
# 3  partly-cloudy-day  VIJP,remote,42348099999
# 4  partly-cloudy-day         VIJP,42348099999
#
# [5 rows x 33 columns]

# %%
df1.shape
# Out:
# (1000, 33)

# %%
df5.head()
# Out:
#         name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  rajasthan  2014-01-01     64.5     46.5  54.6          64.5          43.2
# 1  rajasthan  2014-01-02     68.1     39.3  52.7          68.1          39.3
# 2  rajasthan  2014-01-03     66.3     38.0  53.9          66.3          34.4
# 3  rajasthan  2014-01-04     66.2     51.9  58.2          66.2          51.9
# 4  rajasthan  2014-01-05     66.3     50.1  56.9          66.3          50.1
#
#    feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       54.3  40.9      63.2  ...         15.8        7         NaN
# 1       52.7  32.1      53.1  ...         16.2        7         NaN
# 2       53.4  34.6      51.4  ...         13.1        6         NaN
# 3       58.2  48.1      69.7  ...         12.6        6         NaN
# 4       56.9  53.4      89.2  ...         12.9        6         NaN
#
#                sunrise               sunset  moonphase        conditions  \
# 0  2014-01-01T07:15:55  2014-01-01T17:44:37       0.00             Clear
# 1  2014-01-02T07:16:10  2014-01-02T17:45:18       0.03             Clear
# 2  2014-01-03T07:16:25  2014-01-03T17:46:00       0.06  Partially cloudy
# 3  2014-01-04T07:16:38  2014-01-04T17:46:42       0.10  Partially cloudy
# 4  2014-01-05T07:16:49  2014-01-05T17:47:25       0.13  Partially cloudy
#
#                             description               icon  \
# 0  Clear conditions throughout the day.          clear-day
# 1  Clear conditions throughout the day.          clear-day
# 2     Partly cloudy throughout the day.  partly-cloudy-day
# 3     Partly cloudy throughout the day.  partly-cloudy-day
# 4     Partly cloudy throughout the day.                fog
#
#                   stations
# 0  VIJP,remote,42348099999
# 1       remote,42348099999
# 2       remote,42348099999
# 3  VIJP,remote,42348099999
# 4  VIJP,remote,42348099999
#
# [5 rows x 33 columns]

# %%
df5.shape
# Out:
# (353, 33)

# %%
combine_df = pd.concat([df1,df2, df3, df4, df5] , ignore_index = True)

# %%
combine_df.shape
# Out:
# (4349, 33)

# %%
combine_df.head()
# Out:
#         name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  rajasthan  2023-05-02     89.6     71.4  79.4          90.3          71.4
# 1  rajasthan  2023-05-03     89.6     71.6  78.9          90.3          71.6
# 2  rajasthan  2023-05-04     89.6     69.6  79.8          92.3          69.6
# 3  rajasthan  2023-05-05     95.1     75.2  85.4          95.3          75.2
# 4  rajasthan  2023-05-06     98.6     77.0  87.1          97.8          77.0
#
#    feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       79.9  65.2      64.3  ...         23.3        9        10.0
# 1       79.2  64.5      63.7  ...         24.5       10        10.0
# 2       80.9  65.3      63.5  ...         23.5        9        10.0
# 3       85.6  62.4      48.9  ...         23.3        8        10.0
# 4       86.8  59.3      41.0  ...         25.8       10        10.0
#
#                sunrise               sunset  moonphase  \
# 0  2023-05-02T05:48:07  2023-05-02T18:59:57       0.39
# 1  2023-05-03T05:47:21  2023-05-03T19:00:30       0.42
# 2  2023-05-04T05:46:35  2023-05-04T19:01:04       0.45
# 3  2023-05-05T05:45:51  2023-05-05T19:01:37       0.50
# 4  2023-05-06T05:45:08  2023-05-06T19:02:10       0.52
#
#                conditions                                        description  \
# 0        Partially cloudy                  Partly cloudy throughout the day.
# 1  Rain, Partially cloudy  Partly cloudy throughout the day with late aft...
# 2  Rain, Partially cloudy  Partly cloudy throughout the day with afternoo...
# 3        Partially cloudy                  Partly cloudy throughout the day.
# 4        Partially cloudy                  Becoming cloudy in the afternoon.
#
#                 icon                 stations
# 0  partly-cloudy-day  VIJP,remote,42348099999
# 1               rain         VIJP,42348099999
# 2               rain         VIJP,42348099999
# 3  partly-cloudy-day  VIJP,remote,42348099999
# 4  partly-cloudy-day         VIJP,42348099999
#
# [5 rows x 33 columns]

# %%
selected_columns = ['datetime', 'tempmax', 'temp', 'humidity', 'windspeed','winddir',
                    'precip', 'dew', 'cloudcover', 'solarradiation']

df = combine_df[selected_columns]

# %%
df.head()
# Out:
#      datetime  tempmax  temp  humidity  windspeed  winddir  precip   dew  \
# 0  2023-05-02     89.6  79.4      64.3       15.0     89.9   0.000  65.2
# 1  2023-05-03     89.6  78.9      63.7       15.0    136.8   0.118  64.5
# 2  2023-05-04     89.6  79.8      63.5       10.3    102.7   0.079  65.3
# 3  2023-05-05     95.1  85.4      48.9        6.9     75.4   0.000  62.4
# 4  2023-05-06     98.6  87.1      41.0       11.4    336.5   0.000  59.3
#
#    cloudcover  solarradiation
# 0        57.3           271.5
# 1        55.7           284.0
# 2        35.7           271.6
# 3        44.6           269.7
# 4        33.2           298.3

# %%
cols = ['tempmax', 'temp', 'dew']

for col in cols:
    df[col] = (df[col] - 32) / 1.8
    df[col] = df[col].round(2)

# %%
df['windspeed'] = df['windspeed'] * 1.60934

# %%
import numpy as np

def calculate_relative_humidity(T, Dp):
    beta = 17.625
    lam = 243.04
    
    RH = 100 * (
        np.exp((beta * Dp) / (lam + Dp)) /
        np.exp((beta * T) / (lam + T))
    )
    return RH

# %%
df['calculated_RH'] = calculate_relative_humidity(
    df['temp'],
    df['dew']
)

# %%
df['calculated_RH'].round(2)
df['calculated_RH'] = df['calculated_RH'].clip(0, 100)

# %%
df[['humidity', 'calculated_RH']].describe()
# Out:
#           humidity  calculated_RH
# count  4349.000000    4349.000000
# mean     51.738630      49.740187
# std      21.100206      21.588809
# min       9.200000       7.945366
# 25%      35.900000      33.322419
# 50%      48.700000      45.881175
# 75%      68.400000      66.951645
# max      98.900000      98.913012

# %%
df.head(5)
# Out:
#      datetime  tempmax   temp  humidity  windspeed  winddir  precip    dew  \
# 0  2023-05-02    32.00  26.33      64.3  24.140100     89.9   0.000  18.44
# 1  2023-05-03    32.00  26.06      63.7  24.140100    136.8   0.118  18.06
# 2  2023-05-04    32.00  26.56      63.5  16.576202    102.7   0.079  18.50
# 3  2023-05-05    35.06  29.67      48.9  11.104446     75.4   0.000  16.89
# 4  2023-05-06    37.00  30.61      41.0  18.346476    336.5   0.000  15.17
#
#    cloudcover  solarradiation  calculated_RH
# 0        57.3           271.5      61.888259
# 1        55.7           284.0      61.402082
# 2        35.7           271.6      61.284212
# 3        44.6           269.7      46.195410
# 4        33.2           298.3      39.218518

# %%
df['datetime'] = pd.to_datetime(df['datetime'], format='mixed', dayfirst=True)
df['month'] = df['datetime'].dt.month

# %%
df_hot = df
df_hot['month'].nunique()
# Out:
# 12

# %%
df_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4349 entries, 0 to 4348
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   datetime        4349 non-null   datetime64[ns]
#  1   tempmax         4349 non-null   float64
#  2   temp            4349 non-null   float64
#  3   humidity        4349 non-null   float64
#  4   windspeed       4349 non-null   float64
#  5   winddir         4349 non-null   float64
#  6   precip          4349 non-null   float64
#  7   dew             4349 non-null   float64
#  8   cloudcover      4349 non-null   float64
#  9   solarradiation  4349 non-null   float64
#  10  calculated_RH   4349 non-null   float64
#  11  month           4349 non-null   int32
# dtypes: datetime64[ns](1), float64(10), int32(1)
# memory usage: 390.9 KB

# %%
df_hot.isnull().sum()
# Out:
# datetime          0
# tempmax           0
# temp              0
# humidity          0
# windspeed         0
# winddir           0
# precip            0
# dew               0
# cloudcover        0
# solarradiation    0
# calculated_RH     0
# month             0
# dtype: int64

# %%
df_hot.describe()
# Out:
#                             datetime      tempmax         temp     humidity  \
# count                           4349  4349.000000  4349.000000  4349.000000
# mean   2020-01-11 02:51:30.917452288    31.554148    26.003171    51.738630
# min              2014-01-01 00:00:00    12.000000     7.720000     9.200000
# 25%              2016-12-23 00:00:00    27.000000    20.440000    35.900000
# 50%              2019-12-15 00:00:00    32.000000    27.390000    48.700000
# 75%              2023-02-03 00:00:00    36.000000    30.610000    68.400000
# max              2026-01-25 00:00:00    46.000000    40.220000    98.900000
# std                              NaN     6.323016     6.547468    21.100206
#
#          windspeed      winddir       precip          dew   cloudcover  \
# count  4349.000000  4349.000000  4349.000000  4349.000000  4349.000000
# mean     17.061594   200.337710     0.081372    13.137255    33.845896
# min       0.000000     0.000000     0.000000    -9.390000     0.000000
# 25%      12.230984    90.000000     0.000000     6.830000     8.300000
# 50%      15.771532   247.900000     0.000000    11.670000    31.400000
# 75%      20.599552   297.600000     0.000000    20.670000    52.900000
# max     263.127090   359.900000     8.387000    27.890000   100.000000
# std       8.736525   109.898811     0.367773     7.905942    27.466523
#
#        solarradiation  calculated_RH        month
# count     4349.000000    4349.000000  4349.000000
# mean       220.308508      49.740187     6.488848
# min          0.000000       7.945366     1.000000
# 25%        180.400000      33.322419     3.000000
# 50%        217.700000      45.881175     6.000000
# 75%        265.800000      66.951645    10.000000
# max        342.100000      98.913012    12.000000
# std         58.700546      21.588809     3.486823

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df_hot['datetime'], df_hot['tempmax'])
plt.title("Daily Maximum Temperature – Rajasthan (Summer)")
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
monthly_avg = df_hot.groupby('month')['tempmax'].mean()

monthly_avg.plot(kind='bar', title="Average Summer Temperature (Rajasthan)")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
df_hot['heatwave'] = df_hot['tempmax'] >= 43

# %%
df.head()
# Out:
#     datetime  tempmax   temp  humidity  windspeed  winddir  precip    dew  \
# 0 2023-05-02    32.00  26.33      64.3  24.140100     89.9   0.000  18.44
# 1 2023-05-03    32.00  26.06      63.7  24.140100    136.8   0.118  18.06
# 2 2023-05-04    32.00  26.56      63.5  16.576202    102.7   0.079  18.50
# 3 2023-05-05    35.06  29.67      48.9  11.104446     75.4   0.000  16.89
# 4 2023-05-06    37.00  30.61      41.0  18.346476    336.5   0.000  15.17
#
#    cloudcover  solarradiation  calculated_RH  month  heatwave
# 0        57.3           271.5      61.888259      5     False
# 1        55.7           284.0      61.402082      5     False
# 2        35.7           271.6      61.284212      5     False
# 3        44.6           269.7      46.195410      5     False
# 4        33.2           298.3      39.218518      5     False

# %%
df_hot['heatwave'].value_counts()
# Out:
# heatwave
# False    4229
# True      120
# Name: count, dtype: int64

# %%
df_hot['year'] = df_hot['datetime'].dt.year

# %%
heatwave_days = df_hot.groupby('year')['heatwave'].sum()

plt.figure(figsize=(10,4))
plt.scatter(heatwave_days.index, heatwave_days.values, marker='o')
plt.title("Year-wise Heatwave Days in Rajasthan")
plt.xlabel("Year")
plt.ylabel("Number of Heatwave Days")
plt.show()

# %%
corr = df_hot.corr()

# %%
corr
# Out:
#                 datetime   tempmax      temp  humidity  windspeed   winddir  \
# datetime        1.000000 -0.062483 -0.034081  0.140369  -0.020571 -0.055225
# tempmax        -0.062483  1.000000  0.968358 -0.439611   0.320345  0.271970
# temp           -0.034081  0.968358  1.000000 -0.291854   0.350160  0.249715
# humidity        0.140369 -0.439611 -0.291854  1.000000  -0.043524 -0.195720
# windspeed      -0.020571  0.320345  0.350160 -0.043524   1.000000  0.089183
# winddir        -0.055225  0.271970  0.249715 -0.195720   0.089183  1.000000
# precip          0.054349 -0.023448  0.039702  0.332179   0.053301  0.017631
# dew             0.111837  0.284482  0.438965  0.705756   0.209355 -0.022902
# cloudcover      0.029942  0.048247  0.214566  0.635602   0.194767 -0.103747
# solarradiation -0.080998  0.686260  0.588528 -0.711633   0.238125  0.240507
# calculated_RH   0.146314 -0.412564 -0.257616  0.998039  -0.028324 -0.196662
# month           0.065929  0.030576  0.054141  0.175085  -0.140894 -0.013113
# heatwave       -0.032901  0.326319  0.293969 -0.233609   0.110041  0.112113
# year            0.996532 -0.064937 -0.038402  0.126039  -0.008672 -0.053987
#
#                   precip       dew  cloudcover  solarradiation  calculated_RH  \
# datetime        0.054349  0.111837    0.029942       -0.080998       0.146314
# tempmax        -0.023448  0.284482    0.048247        0.686260      -0.412564
# temp            0.039702  0.438965    0.214566        0.588528      -0.257616
# humidity        0.332179  0.705756    0.635602       -0.711633       0.998039
# windspeed       0.053301  0.209355    0.194767        0.238125      -0.028324
# winddir         0.017631 -0.022902   -0.103747        0.240507      -0.196662
# precip          1.000000  0.296747    0.354035       -0.271923       0.338559
# dew             0.296747  1.000000    0.717998       -0.233936       0.727659
# cloudcover      0.354035  0.717998    1.000000       -0.395467       0.659353
# solarradiation -0.271923 -0.233936   -0.395467        1.000000      -0.703049
# calculated_RH   0.338559  0.727659    0.659353       -0.703049       1.000000
# month           0.050406  0.246183    0.028476       -0.309315       0.178229
# heatwave       -0.036401 -0.055301   -0.082503        0.250198      -0.228077
# year            0.050225  0.091746    0.027727       -0.055202       0.131749
#
#                    month  heatwave      year
# datetime        0.065929 -0.032901  0.996532
# tempmax         0.030576  0.326319 -0.064937
# temp            0.054141  0.293969 -0.038402
# humidity        0.175085 -0.233609  0.126039
# windspeed      -0.140894  0.110041 -0.008672
# winddir        -0.013113  0.112113 -0.053987
# precip          0.050406 -0.036401  0.050225
# dew             0.246183 -0.055301  0.091746
# cloudcover      0.028476 -0.082503  0.027727
# solarradiation -0.309315  0.250198 -0.055202
# calculated_RH   0.178229 -0.228077  0.131749
# month           1.000000 -0.056233 -0.017050
# heatwave       -0.056233  1.000000 -0.028363
# year           -0.017050 -0.028363  1.000000

# %%
import seaborn as sns

plt.figure(figsize = (12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
df_hot = df_hot.drop('heatwave', axis=1)

df_hot.to_csv('df_hot.csv', index= False)
